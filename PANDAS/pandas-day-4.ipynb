# %%
import pandas as pd
#isna, dropna, fillna)
df = pd.read_csv("C:\\Users\\user\\my_snippet\\synthetic_dataset.csv",encoding="utf-8")

# %%
df.head()
df[["Price","Rating"]]
df[(df["Stock"] == "In Stock") & (df["Rating"]>4)]
df.isna().sum()
df.fillna("Unknown")
df.groupby("Category")["Price"].agg('mean')
df.groupby("Category")["Price"].mean()
df.groupby("Category")["Discount"].agg('sum')
df.groupby("Stock").size()
df.groupby("Category")["Rating"].mean().sort_values(ascending=False)
df.groupby("Category")["Rating"].mean().idxmax()
# Out:
# 'D'
