# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\user\my_snippet\DataSets\synthetic_dataset.csv',encoding='UTF-8')
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df.isnull().sum()
df = df.dropna(subset='Price')
df = df.drop_duplicates()

# %%
df['Category'] = df['Category'].fillna('X')
df['Rating'] = df['Rating'].fillna(df['Rating'].median())

# %%
df['Price'].plot(kind='hist',bins=30)
# #df['Stock'].value_counts().plot(kind='hist',bins=30)
df['Discount'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# df.plot(kind='scatter',x='Price',y='Rating')
#df.plot(kind='scatter',x='Discount',y='Rating')

# %%
df['Category'] = df['Category'].fillna('X')
g = df.groupby('Category')
g.agg(avg=('Price','mean'))
g['Price'].sum()
g['Rating'].agg(['max','mean','min'])
# Out:
#                max      mean       min
# Category
# A         4.992002  3.086006  1.016958
# B         4.985116  3.091016  1.013644
# C         4.992309  2.971151  1.000366
# D         4.989577  3.101098  1.003437
# X         4.997818  3.057752  1.003103

# %%
df.groupby('Stock')['Rating'].mean()
#widest price range
df.boxplot(by='Category',column='Price')
# Out:
# <Axes: title={'center': 'Price'}, xlabel='Category'>

# %%
df.loc[:5,:]
# Out:
#   Category   Price    Rating         Stock  Discount
# 0        X  5548.0  1.870322           NaN       0.0
# 1        X  3045.0  4.757798           NaN      38.0
# 2        X  4004.0  3.082060      In Stock       0.0
# 3        X  4808.0  1.492085           NaN      33.0
# 4        X  1817.0  3.082060  Out of Stock      23.0
# 5        X  3522.0  3.082060           NaN       NaN

# %%
df['Category'] = df['Category'].fillna('Unknown')
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount   price FilledCategory
# 0  Unknown  5548.0  1.870322           NaN       0.0  5548.0              X
# 1  Unknown  3045.0  4.757798           NaN      38.0  3045.0              X
# 2  Unknown  4004.0       NaN      In Stock       0.0  4004.0              X
# 3  Unknown  4808.0  1.492085           NaN      33.0  4808.0              X
# 4  Unknown  1817.0       NaN  Out of Stock      23.0  1817.0              X

# %%
df['Price'].plot(kind='hist', bins=30)
# df['Stock'].value_counts().plot(kind='bar')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='Price', y='Rating')
# df.plot(kind='scatter', x='Discount', y='Rating')
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
#df['Rating'].plot(kind='kde')
