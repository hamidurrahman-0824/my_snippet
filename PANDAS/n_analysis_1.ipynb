# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\my_snippet\synthetic_dataset.csv',encoding='UTF-8')
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df['Rating'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %%
df['price'] = df['Price'].dropna()
df['price'].agg(['sum','mean'])
#df['Price'].dropna().agg(['sum','mean'])
# Out:
# sum     2.101107e+07
# mean    5.016971e+03
# Name: price, dtype: float64

# %%
df['Rating'].dropna().agg(['max','mean','min'])
# Out:
# max     4.997818
# mean    3.038293
# min     1.000366
# Name: Rating, dtype: float64

# %%
df['Discount'].sum()
# Out:
# np.float64(97331.0)

# %%
df['Stock'].value_counts()
# Out:
# Stock
# In Stock        1513
# Out of Stock    1497
# Name: count, dtype: int64

# %%
df['Category'].fillna('X')
g = df.groupby('Category')
g['Price'].sum()
g['Rating'].agg(['max','mean','min'])
# Out:
#                max      mean       min
# Category
# A         4.992002  3.089706  1.016958
# B         4.985116  3.098575  1.013644
# C         4.992309  2.878008  1.000366
# D         4.989577  3.116892  1.003437

# %%
g = df.groupby('FilledCategory')
g['Price'].agg(['max','sum','mean'])
g['Rating'].agg(['mean','max','mean'])
g['Stock'].value_counts()
g['Discount'].agg(['max','min','mean','sum'])

# %%
df.loc[:5,:]
# Out:
#   Category   Price    Rating         Stock  Discount   price
# 0      NaN  5548.0  1.870322           NaN       0.0  5548.0
# 1      NaN  3045.0  4.757798           NaN      38.0  3045.0
# 2      NaN  4004.0       NaN      In Stock       0.0  4004.0
# 3      NaN  4808.0  1.492085           NaN      33.0  4808.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0  1817.0
# 5      NaN  3522.0       NaN           NaN       NaN  3522.0

# %%
g = df.groupby('FilledCategory')['Price'].sum()

# %%
df['Category'] = df['Category'].fillna('Unknown')
df.head()
# Out:
#   Category   Price    Rating         Stock  Discount   price FilledCategory
# 0  Unknown  5548.0  1.870322           NaN       0.0  5548.0              X
# 1  Unknown  3045.0  4.757798           NaN      38.0  3045.0              X
# 2  Unknown  4004.0       NaN      In Stock       0.0  4004.0              X
# 3  Unknown  4808.0  1.492085           NaN      33.0  4808.0              X
# 4  Unknown  1817.0       NaN  Out of Stock      23.0  1817.0              X

# %%
df['Price'].plot(kind='hist', bins=30)
df['Stock'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Stock', ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='Price', y='Rating')
df.plot(kind='scatter', x='Discount', y='Rating')
# Out:
# <Axes: xlabel='Discount', ylabel='Rating'>
