# %%
import pandas as pd
df = pd.read_csv("tested.csv")
df1 = pd.read_csv("employees.csv")
df2 = pd.read_csv("departments.csv")
df1,df2
# Out:
# (   emp_id     name dept_id
#  0     101    Alice      D1
#  1     102      Bob      D2
#  2     103  Charlie      D1
#  3     104    David      D3
#  4     105      Eve      D4,
#    dept_id    dept_name  location
#  0      D1  Engineering  New York
#  1      D2    Marketing    London
#  2      D3        Sales     Tokyo
#  3      D5      Finance     Paris)
