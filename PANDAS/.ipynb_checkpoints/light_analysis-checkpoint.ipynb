# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\my_snippet\e-commerce.csv",encoding='latin1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df['DateTime'] = pd.to_datetime(df['InvoiceDate'],format="%m/%d/%Y %H:%M")
df['month'] = df['DateTime'].dt.to_period('M')
g = df.groupby('month')['revenue'].sum()
g.plot(x=g.index,y=g.values,marker='o')
import matplotlib.pyplot as plt
#g = df.groupby('month')['CustomerID'].nunique()
g.plot()
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.xticks()
plt.show()

# %%
df['revenue'] = df['Quantity']*df['UnitPrice']
df['revenue'].sum()
# Out:
# np.float64(9747747.934)

# %%
df.groupby('StockCode')['revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# StockCode
# DOT       206245.48
# 22423     164762.19
# 47566      98302.98
# 85123A     97894.50
# 85099B     92356.03
# Name: revenue, dtype: float64

# %%
df.groupby('Country')['revenue'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          8187806.364
# Netherlands              284661.540
# EIRE                     263276.820
# Germany                  221698.210
# France                   197403.900
# Australia                137077.270
# Switzerland               56385.350
# Spain                     54774.580
# Belgium                   40910.960
# Sweden                    36595.910
# Japan                     35340.620
# Norway                    35163.460
# Portugal                  29367.020
# Finland                   22326.740
# Channel Islands           20086.290
# Denmark                   18768.140
# Italy                     16890.510
# Cyprus                    12946.290
# Austria                   10154.320
# Hong Kong                 10117.040
# Singapore                  9120.390
# Israel                     7907.820
# Poland                     7213.140
# Unspecified                4749.790
# Greece                     4710.520
# Iceland                    4310.000
# Canada                     3666.380
# Malta                      2505.470
# United Arab Emirates       1902.280
# USA                        1730.920
# Lebanon                    1693.880
# Lithuania                  1661.060
# European Community         1291.750
# Brazil                     1143.600
# RSA                        1002.310
# Czech Republic              707.720
# Bahrain                     548.400
# Saudi Arabia                131.170
# Name: revenue, dtype: float64

# %%
df.groupby('CustomerID')['revenue'].mean()
# Out:
# CustomerID
# 12346.0     0.000000
# 12347.0    23.681319
# 12348.0    57.975484
# 12349.0    24.076027
# 12350.0    19.670588
#              ...
# 18280.0    18.060000
# 18281.0    11.545714
# 18282.0    13.584615
# 18283.0     2.771005
# 18287.0    26.246857
# Name: revenue, Length: 4372, dtype: float64

# %%
len(df['InvoiceNo']),df['InvoiceNo'].nunique()
# Out:
# (541909, 25900)

# %%
len(df['Description']),df['Description'].nunique()
# Out:
# (541909, 4223)

# %%
df.groupby('month')['revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# month
# 2011-11    1461756.250
# 2011-10    1070704.670
# 2011-09    1019687.622
# 2010-12     748957.020
# 2011-05     723333.510
# Freq: M, Name: revenue, dtype: float64

# %%
df['hour'] = df['DateTime'].dt.hour
g = df.groupby('hour')['revenue'].sum()
g.plot()
# Out:
# <Axes: xlabel='hour'>

# %%
df.groupby('Description')['revenue'].sum().sort_values(ascending=False)
# Out:
# Description
# DOTCOM POSTAGE                        206245.480
# REGENCY CAKESTAND 3 TIER              164762.190
# WHITE HANGING HEART T-LIGHT HOLDER     99668.470
# PARTY BUNTING                          98302.980
# JUMBO BAG RED RETROSPOT                92356.030
#                                          ...
# Bank Charges                           -7175.639
# CRUK Commission                        -7933.430
# Adjust bad debt                       -11062.060
# Manual                                -68671.640
# AMAZON FEE                           -221520.500
# Name: revenue, Length: 4223, dtype: float64

# %%
g = df.groupby('Country')['Description'].value_counts().reset_index()
g.groupby("Country")['Description'].value_counts().head(3)
# Out:
# Country    Description
# Australia  SET OF 3 CAKE TINS PANTRY DESIGN     1
#            ANIMALS AND NATURE WALL ART          1
#            BUFFALO BILL WALL ART                1
# Name: count, dtype: int64

# %%
#numbr of transaction per month
#df.groupby('month')['CustomerID'].nunique().plot()#accurate method of sales trend,use day hour etc
df.groupby('month')['revenue'].sum().plot(marker='o')#consider every row as new transaction,includes duplicate row as new element,not accurate
# Out:
# <Axes: xlabel='month'>

# %%
#average basket size 
df.groupby('CustomerID')['Quantity'].sum()
#country-wise performance:total customer and total revenue
df.groupby('Country').agg({'CustomerID':'nunique',
                           'revenue':'sum'}).idxmax()
# Out:
# CustomerID    United Kingdom
# revenue       United Kingdom
# dtype: str

# %%
df.groupby('Country')['Description'].value_counts().groupby(level=0).head(3)
# Out:
# Country         Description
# Australia       SET OF 3 CAKE TINS PANTRY DESIGN         10
#                 LUNCH BAG RED RETROSPOT                   9
#                 RED TOADSTOOL LED NIGHT LIGHT             9
# Austria         POSTAGE                                  14
#                 ROUND SNACK BOXES SET OF4 WOODLAND        4
#                                                        ...
# United Kingdom  JUMBO BAG RED RETROSPOT                2001
#                 REGENCY CAKESTAND 3 TIER               1859
# Unspecified     3 STRIPEY MICE FELTCRAFT                  4
#                 MINI JIGSAW CIRCUS PARADE                 3
#                 SET OF 6 3D KIT CARDS FOR KIDS            3
# Name: count, Length: 114, dtype: int64
