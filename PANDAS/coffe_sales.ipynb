# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\user\\my_snippet\\DataSets\\synthetic_dataset.csv")
df.shape
# Out:
# (4362, 5)

# %%
df.notna().sum()
# Out:
# Category    1614
# Price       4188
# Rating      2312
# Stock       3010
# Discount    3970
# dtype: int64

# %%
df.dropna().head(5)
# Out:
#    Category   Price    Rating         Stock  Discount
# 6         C   667.0  3.668341      In Stock      41.0
# 7         A  7125.0  4.983998  Out of Stock       7.0
# 8         A  2777.0  2.678384      In Stock       6.0
# 11        A  3772.0  4.890750      In Stock      45.0
# 15        A  7936.0  3.032832      In Stock      44.0

# %%
df.isnull().sum()
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64
