# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\user\\my_snippet\\synthetic_dataset.csv")
df.head(10)
df.tail(3)
df.head(0)#column
df.loc[0,:]
df.iloc[0,:]#end
df.shape
df["Price"]
df[["Price","Rating"]]
df[df["Price"]>1000]
df[df["Stock"] == "In Stock"]
df[df["Stock"].str.contains("In Stock")]
df[(df["Rating"]>4)&(df["Price"]>2000)]
df[df["Category"]=="D"]#category = "A","B","C","D"
df.isna().sum()
df.dropna()
df["Discount"].fillna(10)#already 0, let put 10 to all
df.groupby("Category")["Price"].mean()
df.groupby("Category")["Discount"].sum()
df.groupby("Stock").size()
df.groupby("Stock").count()#non NaN
df.sort_values("Price",ascending=False)
df.describe()
df.groupby("Category")["Rating"].mean().idxmax()
df.to_csv("grand_quiz_out.csv",index=False)
#value_counts()
